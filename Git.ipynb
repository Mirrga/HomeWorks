# %% [markdown]
# <a href="https://colab.research.google.com/github/Mirrga/HomeWorks/blob/main/Git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 211602.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 211957.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 212044.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 212113.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 212250.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 212455.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 212955.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 213037.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 213137.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 213314.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 213815.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 213911.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-27 214213.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-28 183536.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-28 184309.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-28 184905.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-28 184924.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-28 185053.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-29 223526.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-29 223643.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-04-29 223806.png](data:image/png;base64,...)
